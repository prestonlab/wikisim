# %%
import os
import matplotlib.pyplot as plt
from wikisim import figures

model_dir = '/Users/morton/Dropbox/work/bender/batch/models3'
roi_dir = '/Users/morton/Dropbox/work/bender/batch/glm/prex_stim2/roi'
fig_dir = '/Users/morton/Dropbox/work/bender/figs_wikisim2/geo'
if not os.path.exists(fig_dir):
    os.makedirs(fig_dir)

# %%
figsize=(4, 3)
kwargs = {'ylim': (-.06, .06)}
control_models = ['hmax', 'wiki_use1']

# %%
fig, ax = plt.subplots(figsize=figsize)
g = figures.plot_roi_resid_geo(
    roi_dir, 'b_hopa_prec', 'PREC', model_dir, control_models
)
g.set(**kwargs)
fig.savefig(os.path.join(fig_dir, 'prec_geo_dist_resid.pdf'))
